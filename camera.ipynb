# %%
from imutils import face_utils
import dlib
import cv2
import os

# %%
img = cv2.imread("drunk3.jpg")

# %%
arr = img

# %%
arr[:,:,::-1]
# Out:
# array([[[234, 236, 223],
#         [234, 236, 223],
#         [234, 236, 223],
#         ...,
#         [ 87,  48,  49],
#         [ 81,  45,  45],
#         [ 79,  43,  43]],
#
#        [[234, 236, 223],
#         [234, 236, 223],
#         [234, 236, 223],
#         ...,
#         [ 86,  47,  48],
#         [ 80,  44,  44],
#         [ 78,  42,  42]],
#
#        [[234, 236, 223],
#         [234, 236, 223],
#         [234, 236, 223],
#         ...,
#         [ 85,  46,  47],
#         [ 79,  43,  43],
#         [ 76,  40,  40]],
#
#        ...,
#        [[102,  98,  99],
#         [102,  98,  99],
#         [101,  97,  98],
#         ...,
#         [170,  88,  66],
#         [177,  95,  73],
#         [181,  99,  75]],
#
#        [[102,  98,  99],
#         [102,  98,  99],
#         [101,  97,  98],
#         ...,
#         [179,  92,  72],
#         [184, 100,  76],
#         [188, 104,  78]],
#
#        [[102,  98,  99],
#         [102,  98,  99],
#         [101,  97,  98],
# ...

# %%
cap = cv2.VideoCapture('rtsp://192.168.1.60/stream2')

#判断是否正常开启

print(cap.isOpened())
# Out:
# False

# %%
a = str(img)

# %%
a
# Out:
# '[[[223 236 234]\n  [223 236 234]\n  [223 236 234]\n  ..., \n  [ 49  48  87]\n  [ 45  45  81]\n  [ 43  43  79]]\n\n [[223 236 234]\n  [223 236 234]\n  [223 236 234]\n  ..., \n  [ 48  47  86]\n  [ 44  44  80]\n  [ 42  42  78]]\n\n [[223 236 234]\n  [223 236 234]\n  [223 236 234]\n  ..., \n  [ 47  46  85]\n  [ 43  43  79]\n  [ 40  40  76]]\n\n ..., \n [[ 99  98 102]\n  [ 99  98 102]\n  [ 98  97 101]\n  ..., \n  [ 66  88 170]\n  [ 73  95 177]\n  [ 75  99 181]]\n\n [[ 99  98 102]\n  [ 99  98 102]\n  [ 98  97 101]\n  ..., \n  [ 72  92 179]\n  [ 76 100 184]\n  [ 78 104 188]]\n\n [[ 99  98 102]\n  [ 99  98 102]\n  [ 98  97 101]\n  ..., \n  [ 75  97 185]\n  [ 80 103 189]\n  [ 82 107 193]]]'

# %%
len(a.replace('[','').replace(']','').split('\n'))
# Out:
# 48

# %%
list(img)
# Out:
# [array([[223, 236, 234],
#         [223, 236, 234],
#         [223, 236, 234],
#         ...,
#         [ 49,  48,  87],
#         [ 45,  45,  81],
#         [ 43,  43,  79]], dtype=uint8), array([[223, 236, 234],
#         [223, 236, 234],
#         [223, 236, 234],
#         ...,
#         [ 48,  47,  86],
#         [ 44,  44,  80],
#         [ 42,  42,  78]], dtype=uint8), array([[223, 236, 234],
#         [223, 236, 234],
#         [223, 236, 234],
#         ...,
#         [ 47,  46,  85],
#         [ 43,  43,  79],
#         [ 40,  40,  76]], dtype=uint8), array([[223, 236, 234],
#         [223, 236, 234],
#         [223, 236, 234],
#         ...,
#         [ 46,  45,  84],
#         [ 42,  42,  78],
#         [ 39,  39,  75]], dtype=uint8), array([[223, 236, 234],
#         [223, 236, 234],
#         [223, 236, 234],
#         ...,
#         [ 45,  44,  83],
#         [ 41,  41,  77],
#         [ 38,  38,  74]], dtype=uint8), array([[223, 236, 234],
#         [223, 236, 234],
# ...
