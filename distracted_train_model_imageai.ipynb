# %%
import os  # a conflict in my mac system
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"
from imageai.Prediction.Custom import ModelTraining
model_trainer = ModelTraining()
model_trainer.setModelTypeAsDenseNet()
model_trainer.setDataDirectory(
    "/Users/ranxin/Downloads/state-farm-distracted-driver-detection/imgs")
model_trainer.trainModel(
    num_objects=10,
    num_experiments=10,
    enhance_data=True,
    batch_size=32,
    show_network_summary=True,
    transfer_with_full_training=False,
    transfer_from_model="DenseNet-BC-121-32.h5",
    initial_num_objects=1000)
#     transfer_from_model="squeezenet_weights_tf_dim_ordering_tf_kernels.h5",
#     transfer_with_full_training=False,
#     initial_num_objects=1000)
# Out:
# Training with top layers of the Model
# Training using weights from a pre-trained model
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_21 (InputLayer)           (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_528 (Conv2D)             (None, 112, 112, 64) 9408        input_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_53 (Batc (None, 112, 112, 64) 256         conv2d_528[0][0]
# __________________________________________________________________________________________________
# activation_582 (Activation)     (None, 112, 112, 64) 0           batch_normalization_v1_53[0][0]
# __________________________________________________________________________________________________
# ...
